# %% [markdown]
# ### LINEAR REGRESSION FOR PREDICTING LEADS TO CUSTOMER BASED ON THE LEADS RATING AND RATING

# %% [markdown]
# #### Importing the dataset

# %%
import pandas as pd

# %%
df=pd.read_csv("leadstocustomerFinal.csv", decimal = ',')

# %%
df.head()
# Out:
#    Number      Months  Leads  LeadsToCustomer Average Rating   Campaign Type  \
# 0       1  10/06/2017    146              126            3.7  Email Campaign
# 1       2  08/10/2017     51               31            4.5    Social Media
# 2       3  12/09/2017    191              171            3.1  Youtube Survey
# 3       4  01/11/2018    104               84            1.2         Webinar
# 4       5  04/04/2018     81               61            2.4  Email Campaign
#
#   State
# 0    NY
# 1    MI
# 2    CA
# 3    WV
# 4    KS

# %% [markdown]
# #### Linear Regression

# %%
def linear_regression(X,y):
#SPLIT TEST AND TRAIN
    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

#Linear Regression
    LR = LinearRegression()
    LR.fit(X_train, y_train)
    predictions = LR.predict(X_test)

    print(X_test.shape,X_train.shape,y_test.shape,y_train.shape)
    print('Coefficient of determination(r2_Square):%.2f '% r2_score(y_test, predictions))
    print('Mean Square Error(MSE):%.2f '% np.sqrt(mean_squared_error(y_test, predictions)))
    
    #regressor_OLS = sm.OLS(y_train, X_train).fit()
    
    plt.figure(figsize=(18,10))
    plt.scatter(predictions,y_test,alpha = 0.2)
    plt.xlabel('Predictions')
    plt.ylabel('AQI')
    plt.title("Linear Prediction ")
    plt.show()

# %% [markdown]
# #### Importing the required libraries

# %%
# importing libraries 
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import re
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_log_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score, mean_squared_error

import statsmodels.formula.api as sm

# %% [markdown]
# #### Independent Variables :- Leads and Average Rating, Dependent Variables :- LeadstoCustomers

# %%
from sklearn.linear_model import LinearRegression
X_1=df[['Leads','Average Rating']]
y_1=df['LeadsToCustomer']
linear_regression(X_1,y_1)
# Out:
# (200, 2) (800, 2) (200,) (800,)
# Coefficient of determination(r2_Square):0.66
# Mean Square Error(MSE):30.95
